# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
import statistics as stats

# %%
data=pd.read_csv('Titanic Dataset.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Gender
# 0         A/5 21171   7.2500   NaN        S    male
# 1          PC 17599  71.2833   C85        C  female
# 2  STON/O2. 3101282   7.9250   NaN        S  female
# 3            113803  53.1000  C123        S  female
# 4            373450   8.0500   NaN        S    male

# %%
mean_age=np.mean(data['Age'])
print("Mean Age Of Passengers =",mean_age)
# Out:
# Mean Age Of Passengers = 27.76173076923077

# %%
mean_fare=np.mean(data['Fare'])
print("Mean Fare =",mean_age)
# Out:
# Mean Fare = 27.76173076923077

# %%
median_age=np.median(data['Age'])
print("Value Of Age =", median_age)
# Out:
# Value Of Age = 27.76173076923077

# %%
median_fare=np.median(data['Fare'])
print("Median of fare =", median_fare)
# Out:
# Median of fare = 15.05

# %%
mode_age= stats.mode(data['Age'])
print('Mode Value Of Age =', mode_age)
# Out:
# Mode Value Of Age = 27.76173076923077

# %%
mode_gender=data['Gender'].value_counts().index[0]
print("Mode Of Gender =",mode_gender)
# Out:
# Mode Of Gender = male
